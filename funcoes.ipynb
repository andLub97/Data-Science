# %%
def imprime(mensagem: str):
  print(mensagem)

texto = 'oi'

imprime(mensagem=texto)
# Out:
# oi

# %%
def maiusculo(texto: str) -> str:
  text_maiusculo = texto.upper()
  return text_maiusculo

# %%
nome = 'andré'
nomeMaiusculo = maiusculo(nome)
print(nomeMaiusculo)
# Out:
# ANDRÉ
