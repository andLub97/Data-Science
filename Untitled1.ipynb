# %%
idade = 30

# %%
print(idade)
# Out:
# 30

# %%
nome = 'and'
nome2 = 'ré'
nome3 = f'nome: {nome}{nome2}'
print(nome3)
# Out:
# nome: andré

# %%
print(nome.upper())
# Out:
# AND

# %%
print(nome.find('a'))
# Out:
# 0

# %%
faturamento = 'R$ 35 mil'
faturamento = int(faturamento[3:5])
print(faturamento)
print(type(faturamento))
# Out:
# 35
# <class 'int'>
