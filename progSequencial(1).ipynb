# %%
x = 1

# %%
x = 2

# %% [markdown]
# Ao contrário do que ocorre em C, em python, o valor 2 não é alocado na posição de memporia onde anteriormente 1 estava presente, o que ocorre é que o novo valor é atribuído a um novo endereço de memória.
#
# 10 é atribuído a um endereço de memória e referenciado por x.

# %%
type (1.0)
# Out:
# float

# %%
type({1:'um'})
# Out:
# dict

# %%
type((1,2,3))
# Out:
# tuple

# %%
type('False')
# Out:
# str

# %%
type([1, 2, 3])
# Out:
# list

# %%
type(False)
# Out:
# bool

# %%
type(5 + 7j)
# Out:
# complex

# %%
valorTexto = '26'
numero = int(valorTexto)
print(numero + 10)
# Out:
# 36

# %%
import math
print(math.pi)
print(math.tau)
print(math.e)
# Out:
# 3.141592653589793
# 6.283185307179586
# 2.718281828459045

# %%
5//2
# Out:
# 2

# %%
5/2
# Out:
# 2.5

# %%
5**2
# Out:
# 25

# %%
5**(1/2)
# Out:
# 2.23606797749979

# %%
a = 2
b = 3

# %%
a,b = b,a

# %%
a
# Out:
# 3

# %%
b
# Out:
# 2

# %%
nome = input("informe seu nome: ")
print("olá %s\n" %nome)
enter = input('\npressione <enter> para finalizar...')
# Out:
# informe seu nome: andré
# olá andré
#
#
# pressione <enter> para finalizar...

# %%
v1 = 1
v2 = 10
v3 = 100
v4 = 26.1965

# %%
print("|%3d|"%1)
# Out:
# |  1|

# %%
print("|%-3d|"%1)
# Out:
# |1  |

# %%
print("|%03d|"%v4)
# Out:
# |026|

# %%
print("|%-03d|"%v4)
# Out:
# |26 |

# %%
print("|%6.0f"%v4)
# Out:
# |    26

# %%
valor1 = eval(input("Digite um valor: "))
print(type(valor1))
# Out:
# Digite um valor: 5+8j
# <class 'complex'>

# %%
x, y = eval(input("digite dois valores separados por vírgula: "))
# Out:
# digite dois valores separados por vírgula: 3,4

# %%
print(x)
# Out:
# 3

# %%
print(y)
# Out:
# 4

# %% [markdown]
# comentários de código

# %%
'''Projeto : abc
   Autor:
   Data:
   Versão:
   Revisão:
'''

"""Finalidade

   Este programa faz isso e aquilo
   xx
   xxx
"""

import math #chamada do módulo de recursos matemáticos

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))

print()

print("Olá, %s." % nome)
print("Você tem %i anos de idade." % idade)

print()

print("Olá, %s" % nome, end="")
print(" ,você tem %i anos de idade." % idade)
# Out:
# Digite seu nome: André
# Digite sua idade: 24
#
# Olá, André.
# Você tem 24 anos de idade.
#
# Olá, André ,você tem 24 anos de idade.

# %%
print(1, 2, 3, sep=" | - | ", end=" ***")
# Out:
# 1 | - | 2 | - | 3 ***
