# %%
n = int(input("Insira o valor da tabuada: "))

print()

i = 1

while(i<=10):
  r=n*i
  print("%2d x %2d = %3d" % (n, i, r))
  i = i + 1

enter = input("\nPressione <Enter> para encerrar... ")
# Out:
# Insira o valor da tabuada: 8
#
#  8 x  1 =   8
#  8 x  2 =  16
#  8 x  3 =  24
#  8 x  4 =  32
#  8 x  5 =  40
#  8 x  6 =  48
#  8 x  7 =  56
#  8 x  8 =  64
#  8 x  9 =  72
#  8 x 10 =  80
#
# Pressione <Enter> para encerrar...

# %%
n = int(input("Insira o valor da tabuada: "))
print()

for i in range(1, 11):
  r = n*i
  print("%2d x %2d = %3d" % (n,i,r))
# Out:
# Insira o valor da tabuada: 4
#
#  4 x  1 =   4
#  4 x  2 =   8
#  4 x  3 =  12
#  4 x  4 =  16
#  4 x  5 =  20
#  4 x  6 =  24
#  4 x  7 =  28
#  4 x  8 =  32
#  4 x  9 =  36
#  4 x 10 =  40

# %%
for i in range(1, 13, 2):
  print("%2d" %i)
# Out:
#  1
#  3
#  5
#  7
#  9
# 11

# %%
for i in range(20,0,-2):
  print("%2d"%i)
# Out:
# 20
# 18
# 16
# 14
# 12
# 10
#  8
#  6
#  4
#  2

# %%
a = b = 0

# %%
a
# Out:
# 0

# %%
b
# Out:
# 0
