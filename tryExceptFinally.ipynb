# %%
preco = 132.85
pessoas = 0

try:
  valor_por_pessoa = preco/pessoas
  print(valor_por_pessoa)
except ZeroDivisionError:
  print('Número de pessoas inválido')
# Out:
# Número de pessoas inválido

# %%
preco = 132.85
pessoas = 0

try:
  valor_por_pessoa = preco/pessoas
  print(valor_por_pessoa)
except Exception:
  print('Número de pessoas inválido')
# Out:
# Número de pessoas inválido

# %%
anos = [2019,2020,2021]

try:
  ano_atual = anos[3]
  print(ano_atual)
except Exception as exc:
  print('Descrição: ' + str(exc))
  print('Tipo da exceção: ' + str(type(exc)))
  print('lista de anos menor que o valor escolhido')
# Out:
# Descrição: list index out of range
# Tipo da exceção: <class 'IndexError'>
# lista de anos menor que o valor escolhido

# %%
nome = 'André Lubawski'
idade = 24

try:
  apresentacao = 'oi, meu nome é ' + nome + ' e tenho' + idade + ' anos'
  print(apresentacao)
except TypeError:
  idade = str(idade)
finally:
  print('segunda chance')
  apresentacao = 'oi, meu nome é ' + nome + ' e tenho ' + idade + ' anos'
  print(apresentacao)
# Out:
# segunda chance
# oi, meu nome é André Lubawski e tenho 24 anos
