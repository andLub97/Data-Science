# %%
len('abcde')
# Out:
# 5

# %%
a = 'abcde'
a[2]
# Out:
# 'c'

# %%
'c' in a
# Out:
# True

# %%
a[-1]
# Out:
# 'e'

# %%
a[-2]
# Out:
# 'd'

# %%
a = str(5)
print(a)
# Out:
# 5

# %%
type(a)
# Out:
# str

# %%
faturamento = 1000
custo = 500
print("o faturamento foi de : {} e o custo: {}".format(faturamento,custo))
# Out:
# o faturamento foi de : 1000 e o custo: 500

# %%
texto = 'andré'
print(texto.capitalize())
# Out:
# André

# %%
texto2 = 'ANDRé'
print(texto2.casefold())
# Out:
# andré

# %%
texto.count('d')
# Out:
# 1

# %%
texto.endswith('é')
# Out:
# True

# %%
texto.find('a')
# Out:
# 0

# %%
texto.isalnum()
# Out:
# True

# %%
texto.isalpha()#apenas letras
# Out:
# True

# %%
texto.isnumeric()#apenas números
# Out:
# False

# %%
novoTexto = 'andre@gmail'
print(novoTexto.split('@'))
# Out:
# ['andre', 'gmail']

# %%
frase = '''olá,
meu nome é
andré'''
print(frase.splitlines())
# Out:
# ['olá,', 'meu nome é', 'andré']

# %%
b = ' abcd '
b.strip()
# Out:
# 'abcd'

# %%
b.strip().upper()
# Out:
# 'ABCD'
