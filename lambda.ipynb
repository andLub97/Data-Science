# %%
extrair_provedor = lambda email: email.split(sep='@')[-1]

# %%
email= 'andre.lubb@gmail.com'
print(email)

provedor_email = extrair_provedor(email)
print(provedor_email)
# Out:
# andre.lubb@gmail.com
# gmail.com

# %%
numero_e_par = lambda numero: True if numero % 2 == 0 else False

# %%
for numero in range(0,7):
  if numero_e_par(numero) == True:
    print(f'O número {numero} e´par!\n')
# Out:
# O número 0 e´par!
#
# O número 2 e´par!
#
# O número 4 e´par!
#
# O número 6 e´par!
