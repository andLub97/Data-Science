# %%
class Pessoa(object):

  def __init__(self, nome: str, idade: int, documento: str):
    self.nome = nome
    self.idade = idade
    self.documento = documento

# %%
andre = Pessoa(nome='André', idade = 24, documento='123')

# %%
print(andre.idade)
# Out:
# 24
